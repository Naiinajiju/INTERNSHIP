# %% [markdown]
# <a href="https://colab.research.google.com/github/nayanajiju/INTERNSHIP/blob/main/Internship%20Day%202.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/boston (1).csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.tail(5)
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.isnull()
# Out:
#       crim     zn  indus   chas    nox     rm    age    dis    rad    tax  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False  False  False  False  False
#
#      ptratio      b  lstat   medv
# 0      False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='darkgrid')
plt.figure(figsize=(10,6))

# %%
sns.boxplot(data=df,x='crim',y='tax',palette='Set3')
plt.title('Boxplot of Crim by Tax',fontsize=16)
plt.xlabel('Crim',fontsize=12)
plt.ylabel('Tax',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_2054/4232813130.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='crim',y='tax',palette='Set3')

# %%
sns.boxplot(data=df,x='tax',y='indus',palette='Set3')
plt.title('Boxplot of Tax by indus',fontsize=16)
plt.xlabel('Tax',fontsize=12)
plt.ylabel('Indus',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_2054/3493079179.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='tax',y='indus',palette='Set3')

# %%
sns.barplot(data=df,x='tax',y='indus',palette='Set2')
plt.title('Barplot of Tax by indus',fontsize=16)
plt.xlabel('Tax',fontsize=12)
plt.ylabel('Indus',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_2054/260500017.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x='tax',y='indus',palette='Set2')

# %%
sns.lineplot(data=df,x='tax',y='indus',palette='Set3')
plt.title('Lineplot of Tax by indus',fontsize=16)
plt.xlabel('Tax',fontsize=12)
plt.ylabel('Indus',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_2054/3728226331.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df,x='tax',y='indus',palette='Set3')

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

boston_data=df.copy()

standard_scaler=StandardScaler()


boston_data['crim']=standard_scaler.fit_transform(boston_data[['crim']])
boston_data['zn']=standard_scaler.fit_transform(boston_data[['zn']])
boston_data['indus']=standard_scaler.fit_transform(boston_data[['indus']])
boston_data['nox']=standard_scaler.fit_transform(boston_data[['nox']])
boston_data['rm']=standard_scaler.fit_transform(boston_data[['rm']])
boston_data['age']=standard_scaler.fit_transform(boston_data[['age']])
boston_data['dis']=standard_scaler.fit_transform(boston_data[['dis']])
boston_data['rad']=standard_scaler.fit_transform(boston_data[['rad']])
boston_data['tax']=standard_scaler.fit_transform(boston_data[['tax']])
boston_data['ptratio']=standard_scaler.fit_transform(boston_data[['ptratio']])
boston_data['b']=standard_scaler.fit_transform(boston_data[['b']])
boston_data['lstat']=standard_scaler.fit_transform(boston_data[['lstat']])


boston_data[['crim','zn','indus','nox','rm','age','dis','rad','tax','ptratio','b','lstat']]
# Out:
#          crim        zn     indus       nox        rm       age       dis  \
# 0   -0.419782  0.284830 -1.287909 -0.144217  0.413672 -0.120013  0.140214
# 1   -0.417339 -0.487722 -0.593381 -0.740262  0.194274  0.367166  0.557160
# 2   -0.417342 -0.487722 -0.593381 -0.740262  1.282714 -0.265812  0.557160
# 3   -0.416750 -0.487722 -1.306878 -0.835284  1.016303 -0.809889  1.077737
# 4   -0.412482 -0.487722 -1.306878 -0.835284  1.228577 -0.511180  1.077737
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738  0.158124  0.439316  0.018673 -0.625796
# 502 -0.415249 -0.487722  0.115738  0.158124 -0.234548  0.288933 -0.716639
# 503 -0.413447 -0.487722  0.115738  0.158124  0.984960  0.797449 -0.773684
# 504 -0.407764 -0.487722  0.115738  0.158124  0.725672  0.736996 -0.668437
# 505 -0.415000 -0.487722  0.115738  0.158124 -0.362767  0.434732 -0.613246
#
#           rad       tax   ptratio         b     lstat
# ...

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


x=df.drop(columns=['medv'])
y=df['medv']


x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)


model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# Model Evaluation
r2 = r2_score(y_test, y_pred)
#rmse = mean_squared_error(y_test, y_pred, squared=False)
rmse = mean_squared_error(y_test, y_pred) ** 0.5

print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
# R² Score: 0.6688
# RMSE: 4.9286
